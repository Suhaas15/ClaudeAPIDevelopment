# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "python" or "json" or "regex",
        "solution_criteria": "Must include runtime, memory size, timeout, and basic structure for AWS Lambda configuration."
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result."""
    prompt = f"""
Please solve the following task:

{test_case['task']}

*Respond only with Python, JSON, or a plain Regex
*Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, close_sequences=["```"])
    return output

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
import re
import ast

def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0

def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    #TODO - Grading
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade.get("score", None)
    reasoning = model_grade.get("reasoning", None)

    syntax_score = grade_syntax(output, test_case)

    score = (model_score+syntax_score)/2

    return {
        "test_case": test_case,
        "output": output,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average Score: {average_score:.1f}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average Score: 3.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "test_case": {
#       "task": "Create an AWS Lambda function that processes S3 bucket events and logs the bucket name and object key",
#       "format": "python",
#       "solution_criteria": "Must include event handler function, extract bucket name from event['Records'][0]['s3']['bucket']['name'], extract object key from event['Records'][0]['s3']['object']['key'], and include a print or logging statement"
#     },
#     "output": "# AWS Lambda Function for S3 Bucket Events Processing\n\nI'll create a complete solution for processing S3 bucket events with logging.\n\n## 1. Lambda Function Code\n\n```python\n# lambda_function.py\nimport json\nimport boto3\nimport logging\nfrom typing import Any, Dict\n\n# Initialize logger\nlogger = logging.getLogger()\nlogger.setLevel(logging.INFO)\n\n# Initialize S3 client\ns3_client = boto3.client('s3')\n\n\ndef lambda_handler(event: Dict[str, Any], context: Any) -> Dict[str, Any]:\n    \"\"\"\n    Process S3 bucket events and log bucket name and object key.\n    \n    Args:\n        event: S3 event trigger\n        context: Lambda context object\n        \n    Returns:\n        Response with status code and message\n    \"\"\"\n    try:\n        logger.info(f\"Received event: {json.dumps(event)}\")\n        \n        # Extract S3 records from the event\n        records = event.get('Records', [])\n        \n        if not records:\n            logger.warning(\"No records found in event\")\n            return {\n                'statusCode': 400,\n                'body': json.dumps('No records found in event')\n            }\n        \n        processed_objects = []\n        \n        # Process each record\n        for record in records:\n            try:\n                # Extract S3 information\n                s3_info = record.get('s3', {})\n                bucket_name = s3_info.get('bucket', {}).get('name')\n                object_key = s3_info.get('object', {}).get('key')\n                event_name = record.get('eventName')\n                event_time = record.get('eventTime')\n                \n                # Log the information\n                logger.info(f\"Event: {event_name}\")\n                logger.info(f\"Bucket Name: {bucket_name}\")\n                logger.info(f\"Object Key: {object_key}\")\n                logger.info(f\"Event Time: {event_time}\")\n                \n                # Additional event details\n                event_source = record.get('eventSource')\n                aws_region = record.get('awsRegion')\n                \n                logger.info(f\"Event Source: {event_source}\")\n                logger.info(f\"AWS Region: {aws_region}\")\n                \n                # Create object details dictionary\n                object_details = {\n                    'bucket_name': bucket_name,\n                    'object_key': object_key,\n                    'event_name': event_name,\n                    'event_time': event_time,\n                    'region': aws_region\n                }\n                \n                processed_objects.append(object_details)\n                \n                # Process based on event type\n                if event_name == 's3:ObjectCreated:Put':\n                    logger.info(f\"New object created: s3://{bucket_name}/{object_key}\")\n                    process_new_object(bucket_name, object_key)\n                    \n                elif event_name == 's3:ObjectRemoved:Delete':\n                    logger.info(f\"Object deleted: s3://{bucket_name}/{object_key}\")\n                    process_deleted_object(bucket_name, object_key)\n                    \n                else:\n                    logger.info(f\"Other S3 event: {event_name}\")\n                \n            except Exception as record_error:\n                logger.error(f\"Error processing record: {str(record_error)}\", \n                           exc_info=True)\n                continue\n        \n        logger.info(f\"Successfully processed {len(processed_objects)} objects\")\n        \n        return {\n            'statusCode': 200,\n            'body': json.dumps({\n                'message': 'Successfully processed S3 events',\n                'processed_count': len(processed_objects),\n                'objects': processed_objects\n            })\n        }\n        \n    except Exception as error:\n        logger.error(f\"Error in lambda_handler:  ...
#     "score": 3.0,
#     "reasoning": "The solution demonstrates strong understanding of AWS Lambda S3 event processing and meets all core requirements: it has a proper lambda_handler function, correctly extracts bucket name and object key from the expected event structure, and includes comprehensive logging statements. However, the incomplete code artifact and unnecessary complexity detract from its quality. The missing helper function definitions and unfinished return statement make this non-deployable as-is, despite the solid foundational approach."
#   },
#   {
#     "test_case": {
#       "task": "Generate a CloudFormation template configuration for an S3 bucket with versioning enabled and public access blocked",
#       "format": "json",
#       "solution_criteria": "Must include Resources section with S3 bucket, VersioningConfiguration set to Enabled, PublicAccessBlockConfiguration with all Block properties set to true, and proper AWSTemplateFormatVersion"
#     },
#     "output": "# CloudFormation Template for S3 Bucket with Versioning and Public Access Block\n\n```yaml\nAWSTemplateFormatVersion: '2010-09-09'\nDescription: 'CloudFormation template for S3 bucket with versioning enabled and public access blocked'\n\nParameters:\n  BucketName:\n    Type: String\n    Description: Name of the S3 bucket (must be globally unique)\n    AllowedPattern: '^[a-z0-9][a-z0-9-]*[a-z0-9]$'\n    ConstraintDescription: 'Bucket name must start with lowercase letter or number, contain only lowercase letters, numbers, and hyphens, and end with lowercase letter or number'\n\nResources:\n  S3Bucket:\n    Type: AWS::S3::Bucket\n    Properties:\n      BucketName: !Ref BucketName\n      VersioningConfiguration:\n        Status: Enabled\n      Tags:\n        - Key: Name\n          Value: !Ref BucketName\n        - Key: Environment\n          Value: Production\n\n  S3BucketPublicAccessBlock:\n    Type: AWS::S3::BucketPublicAccessBlock\n    Properties:\n      BucketName: !Ref S3Bucket\n      BlockPublicAcls: true\n      BlockPublicPolicy: true\n      IgnorePublicAcls: true\n      RestrictPublicBuckets: true\n\n  S3BucketPolicy:\n    Type: AWS::S3::BucketPolicy\n    Properties:\n      Bucket: !Ref S3Bucket\n      PolicyText:\n        Version: '2012-10-17'\n        Statement:\n          - Sid: DenyUnencryptedObjectUploads\n            Effect: Deny\n            Principal: '*'\n            Action: 's3:PutObject'\n            Resource: !Sub '${S3Bucket.Arn}/*'\n            Condition:\n              StringNotEquals:\n                's3:x-amz-server-side-encryption': 'AES256'\n          - Sid: DenyInsecureTransport\n            Effect: Deny\n            Principal: '*'\n            Action: 's3:*'\n            Resource:\n              - !GetAtt S3Bucket.Arn\n              - !Sub '${S3Bucket.Arn}/*'\n            Condition:\n              Bool:\n                'aws:SecureTransport': 'false'\n\nOutputs:\n  BucketName:\n    Description: Name of the S3 bucket\n    Value: !Ref S3Bucket\n    Export:\n      Name: !Sub '${AWS::StackName}-BucketName'\n\n  BucketArn:\n    Description: ARN of the S3 bucket\n    Value: !GetAtt S3Bucket.Arn\n    Export:\n      Name: !Sub '${AWS::StackName}-BucketArn'\n\n  BucketDomainName:\n    Description: Domain name of the S3 bucket\n    Value: !GetAtt S3Bucket.DomainName\n    Export:\n      Name: !Sub '${AWS::StackName}-DomainName'\n```\n\n## Alternative JSON Format\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for S3 bucket with versioning enabled and public access blocked\",\n  \"Parameters\": {\n    \"BucketName\": {\n      \"Type\": \"String\",\n      \"Description\": \"Name of the S3 bucket (must be globally unique)\",\n      \"AllowedPattern\": \"^[a-z0-9][a-z0-9-]*[a-z0-9]$\",\n      \"ConstraintDescription\": \"Bucket name must follow S3 naming conventions\"\n    }\n  },\n  \"Resources\": {\n    \"S3Bucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": {\n          \"Ref\": \"BucketName\"\n        },\n        \"VersioningConfiguration\": {\n          \"Status\": \"Enabled\"",
#     "score": 4.0,
#     "reasoning": "The YAML template is production-ready and comprehensively addresses the task requirements with additional security hardening. The core criteria are fully satisfied: proper template version, S3 bucket resource, versioning enabled, and public access block with all four properties true. However, the incomplete JSON example and minor configuration inflexibilities prevent a perfect score."
#   },
#   {
#     "test_case": {
#       "task": "Create a regular expression pattern to validate AWS IAM role ARNs in the format 'arn:aws:iam::123456789012:role/service-role-name'",
#       "format": "regex",
#       "solution_criteria": "Must match valid IAM role ARNs, include arn:aws:iam:: prefix, capture 12-digit account ID, include role/ prefix, and reject invalid formats with wrong separators or missing components"
#     },
#     "output": "# AWS IAM Role ARN Validation Regex\n\nHere's a comprehensive solution with multiple complexity levels:\n\n## Basic Pattern (Simple)\n```regex\narn:aws:iam::\\d{12}:role/[\\w+=,.@-]+\n```\n\n## Standard Pattern (Recommended)\n```regex\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@\\-_/]+$\n```\n\n## Strict Pattern (Most Comprehensive)\n```regex\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@\\-_/]{1,64}$\n```\n\n## Implementation Examples\n\n### Python\n```python\nimport re\n\n# Standard pattern\niam_role_pattern = r'^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@\\-_/]+$'\n\ndef validate_iam_role_arn(arn):\n    return bool(re.match(iam_role_pattern, arn))\n\n# Test cases\ntest_arns = [\n    'arn:aws:iam::123456789012:role/service-role-name',  # \u2713 Valid\n    'arn:aws:iam::123456789012:role/MyRole',             # \u2713 Valid\n    'arn:aws:iam::123456789012:role/path/to/role',       # \u2713 Valid\n    'arn:aws:iam::12345678901:role/invalid',             # \u2717 Invalid (11 digits)\n    'arn:aws:iam::123456789012:user/username',           # \u2717 Invalid (user, not role)\n]\n\nfor arn in test_arns:\n    print(f\"{arn}: {validate_iam_role_arn(arn)}\")\n```\n\n### JavaScript\n```javascript\nconst iamRolePattern = /^arn:aws:iam::\\d{12}:role\\/[a-zA-Z0-9+=,.@\\-_/]+$/;\n\nfunction validateIamRoleArn(arn) {\n    return iamRolePattern.test(arn);\n}\n\n// Test cases\nconst testArns = [\n    'arn:aws:iam::123456789012:role/service-role-name',\n    'arn:aws:iam::123456789012:role/MyRole',\n];\n\ntestArns.forEach(arn => {\n    console.log(`${arn}: ${validateIamRoleArn(arn)}`);\n});\n```\n\n### Java\n```java\nimport java.util.regex.Pattern;\n\npublic class IAMRoleValidator {\n    private static final String IAM_ROLE_PATTERN = \n        \"^arn:aws:iam::\\\\d{12}:role/[a-zA-Z0-9+=,.@\\\\-_/]+$\";\n    \n    private static final Pattern pattern = Pattern.compile(IAM_ROLE_PATTERN);\n    \n    public static boolean validateIamRoleArn(String arn) {\n        return pattern.matcher(arn).matches();\n    }\n}\n```\n\n## Pattern Breakdown\n\n| Component | Description |\n|-----------|-------------|\n| `^arn:aws:iam::` | Fixed prefix for AWS IAM ARNs |\n| `\\d{12}` | AWS Account ID (exactly 12 digits) |\n| `:role/` | Resource type identifier |\n| `[a-zA-Z0-9+=,.@\\-_/]+` | Role name (allowed characters) |\n| `$` | End of string anchor |\n\n## Allowed Characters in Role Name\n- Letters: `a-zA-Z`\n- Numbers: `0-9`\n- Special: `+=,.@-_/`\n- **Max length:** 64 characters (recommended)\n\n## Key Features\n\u2705 Validates AWS Account ID (12 digits)  \n\u2705 Ensures resource type is \"role\"  \n\u2705 Supports path separators (`/`)  \n\u2705 Validates",
#     "score": 3.5,
#     "reasoning": "The solution successfully meets core criteria by validating the ARN structure, account ID format, and resource type. However, it has practical gaps: the recommended 'standard' pattern lacks length constraints that AWS enforces, and the regex permits invalid role name formats like paths with consecutive slashes (e.g., 'role//invalid'). While the implementation examples are well-structured and functional for basic validation, they don't catch these edge cases. The solution would be production-ready with stricter role name validation and consistent enforcement of the 64-character limit across all patterns."
#   }
# ]
