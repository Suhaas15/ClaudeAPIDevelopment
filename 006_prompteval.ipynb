# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "python" or "json" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result."""
    prompt = f"""
Please solve the following task:

{test_case['task']}

*Respond only with Python, JSON, or a plain Regex
*Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, close_sequences=["```"])
    return output

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
import re
import ast

def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0

def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    #TODO - Grading
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade.get("score", None)
    reasoning = model_grade.get("reasoning", None)

    syntax_score = grade_syntax(output, test_case)

    score = (model_score+syntax_score)/2

    return {
        "test_case": test_case,
        "output": output,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average Score: {average_score:.1f}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average Score: 5.3

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and returns just the bucket name.",
#       "format": "python"
#     },
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a Python function that extracts the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"\n    Parse an AWS S3 bucket name from an S3 URI.\n    \n    Args:\n        s3_uri: An S3 URI string (e.g., 's3://my-bucket/path/to/file.txt')\n    \n    Returns:\n        The bucket name as a string\n    \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    if not s3_uri:\n        raise ValueError(\"S3 URI cannot be empty\")\n    \n    if not s3_uri.startswith(\"s3://\"):\n        raise ValueError(\"Invalid S3 URI: must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    uri_without_prefix = s3_uri[5:]\n    \n    # Extract bucket name (everything before the first '/')\n    bucket_name = uri_without_prefix.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"S3 URI does not contain a bucket name\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Basic usage\n    print(parse_s3_bucket_name(\"s3://my-bucket/path/to/file.txt\"))\n    # Output: my-bucket\n    \n    print(parse_s3_bucket_name(\"s3://my-bucket\"))\n    # Output: my-bucket\n    \n    print(parse_s3_bucket_name(\"s3://another-bucket/deep/path/structure/file.txt\"))\n    # Output: another-bucket\n    \n    # Error handling\n    try:\n        parse_s3_bucket_name(\"https://my-bucket.s3.amazonaws.com/file.txt\")\n    except ValueError as e:\n        print(f\"Error: {e}\")\n        # Output: Error: Invalid S3 URI: must start with 's3://'\n    \n    try:\n        parse_s3_bucket_name(\"s3://\")\n    except ValueError as e:\n        print(f\"Error: {e}\")\n        # Output: Error: S3 URI does not contain a bucket name\n```\n\n## Alternative Implementation (Using `urllib.parse`)\n\nFor a more robust solution using standard library URL parsing:\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name_urllib(s3_uri: str) -> str:\n    \"\"\"\n    Parse an AWS S3 bucket name using urllib.\n    \n    Args:\n        s3_uri: An S3 URI string (e.g., 's3://my-bucket/path/to/file.txt')\n    \n    Returns:\n        The bucket name as a string\n    \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    if not s3_uri:\n        raise ValueError(\"S3 URI cannot be empty\")\n    \n    parsed = urlparse(s3_uri)\n    \n    if parsed.scheme != \"s3\":\n        raise ValueError(f\"Invalid S3 URI: scheme must be 's3', got '{parsed.scheme}'\")\n    \n    bucket_name = parsed.netloc\n    \n    if not bucket_name:\n        raise ValueError(\"S3 URI does not contain a bucket name\")\n    \n    return bucket_name\n\n\n# Test the urllib version\nif __name__ == \"__main__\":\n    print(parse_s3_bucket_name_urllib(\"s3://my-bucket/path/to/file.txt\"))\n    # Output: my-bucket\n```\n\n## Comparison\n\n| Approach | Pros | Cons |\n|----------|------|------|\n| **String manipulation** | Simple, no dependencies | Less robust |\n| **urllib.parse** | Standards-based, handles edge cases | Slightly more overhead |\n\n## Key Features\n\n\u2705 **Validates S3 URI format** - Ensures the URI starts with `s3://`  \n\u2705 **Handles various paths** - Works with or without object",
#     "score": 3.5,
#     "reasoning": "The solution correctly solves the core task with two working implementations. The urllib.parse version is properly robust and preferred. However, both lack validation against AWS S3 bucket naming rules, which would be important for production use. The string manipulation version is simple but less maintainable. The inclusion of test cases and comparison is excellent, but the validation gaps represent a notable oversight for an AWS-focused solution."
#   },
#   {
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'company-data'.",
#       "format": "json"
#     },
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data\"\n    },\n    {\n      \"Sid\": \"ReadObjectsInBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data/*\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Specifies the policy language version (required) |\n| **ListBucket** | Allows listing objects in the bucket |\n| **GetBucketLocation** | Allows retrieving bucket region information |\n| **GetObject** | Allows reading object content |\n| **GetObjectVersion** | Allows reading specific object versions (if versioning enabled) |\n| **Resource ARN** | `arn:aws:s3:::company-data` for bucket operations |\n| | `arn:aws:s3:::company-data/*` for object operations |\n\n## Key Features\n\u2705 Read-only access (no Put, Delete, or Write permissions)  \n\u2705 Scoped to the specific 'company-data' bucket  \n\u2705 Follows AWS best practices with descriptive SIDs  \n\u2705 Separates bucket-level and object-level permissions",
#     "score": 4.0,
#     "reasoning": "The policy successfully meets the core requirement of providing read-only S3 access to 'company-data' with proper ARN scoping and permission separation. The implementation is solid for basic read scenarios. However, the inclusion of GetObjectVersion without corresponding versioning-related bucket permissions creates a minor inconsistency. The policy would benefit from either removing version access or adding complementary bucket-level versioning actions. Overall, this is a production-ready policy for standard read-only use cases, though it could be more comprehensive for advanced scenarios."
#   },
#   {
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters, e.g., i-0abcd1234efgh5678).",
#       "format": "regex"
#     },
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression to match valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n- `^` - Start of string\n- `i-` - Literal prefix \"i-\"\n- `[0-9a-f]{17}` - Exactly 17 hexadecimal characters (0-9, a-f)\n- `$` - End of string\n\n## Usage Examples\n\n### Python\n```python\nimport re\n\npattern = r'^i-[0-9a-f]{17}$'\n\n# Valid examples\nprint(re.match(pattern, 'i-0abcd1234efgh5678'))  # Match\nprint(re.match(pattern, 'i-1234567890abcdef0'))  # Match\n\n# Invalid examples\nprint(re.match(pattern, 'i-0abcd1234efgh567'))   # No match (16 chars)\nprint(re.match(pattern, 'i-0abcd1234efgh56789')) # No match (18 chars)\nprint(re.match(pattern, 'i-0abcd1234efghXYZ89')) # No match (non-hex chars)\nprint(re.match(pattern, 'ec2-0abcd1234efgh5678')) # No match (wrong prefix)\n```\n\n### JavaScript\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\n\nconsole.log(pattern.test('i-0abcd1234efgh5678'));  // true\nconsole.log(pattern.test('i-1234567890abcdef0'));  // true\nconsole.log(pattern.test('i-0abcd1234efgh567'));   // false\n```\n\n### Case-Insensitive Version\nIf you need to match uppercase hex characters as well:\n\n```regex\n^i-[0-9a-fA-F]{17}$\n```\n\nThis pattern is strict and validates the exact format of AWS EC2 instance IDs.",
#     "score": 8.5,
#     "reasoning": "The solution demonstrates strong understanding of regex fundamentals and provides a technically correct base pattern. The presentation is professional with good documentation across multiple languages. However, the example with invalid hex characters (g, h) that's marked as matching is a significant error in the technical content. While this doesn't break the actual regex pattern itself, it indicates insufficient validation of the examples provided. The inclusion of a case-insensitive variant shows good practical thinking, though clarity on AWS's actual format would strengthen the answer."
#   }
# ]
