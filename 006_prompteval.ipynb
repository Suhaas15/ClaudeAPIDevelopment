# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "python" or "json" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result."""
    prompt = f"""
Please solve the following task:

{test_case['task']}

*Respond only with Python, JSON, or a plain Regex
*Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, close_sequences=["```"])
    return output

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
import re
import ast

def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0

def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    #TODO - Grading
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade.get("score", None)
    reasoning = model_grade.get("reasoning", None)

    syntax_score = grade_syntax(output, test_case)

    score = (model_score+syntax_score)/2

    return {
        "test_case": test_case,
        "output": output,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average Score: {average_score:.1f}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average Score: 7.00

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and returns just the bucket name."
#     },
#     "output": "# Solution: Parse AWS S3 Bucket Name from S3 URI\n\nHere's a Python function that extracts the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri):\n    \"\"\"\n    Parses an AWS S3 bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): An S3 URI in the format 's3://bucket-name/path/to/file'\n        \n    Returns:\n        str: The S3 bucket name\n        \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n        \n    Examples:\n        >>> parse_s3_bucket_name('s3://my-bucket/path/to/file.txt')\n        'my-bucket'\n        >>> parse_s3_bucket_name('s3://another-bucket/')\n        'another-bucket'\n    \"\"\"\n    if not isinstance(s3_uri, str):\n        raise ValueError(\"S3 URI must be a string\")\n    \n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"Invalid S3 URI: must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    uri_without_prefix = s3_uri[5:]\n    \n    # Split by '/' and get the first part (bucket name)\n    bucket_name = uri_without_prefix.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Invalid S3 URI: bucket name is empty\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Basic test cases\n    test_cases = [\n        ('s3://my-bucket/path/to/file.txt', 'my-bucket'),\n        ('s3://another-bucket/', 'another-bucket'),\n        ('s3://simple-bucket', 'simple-bucket'),\n        ('s3://my-bucket-123/folder/subfolder/file.csv', 'my-bucket-123'),\n        ('s3://bucket.with.dots/data.json', 'bucket.with.dots'),\n    ]\n    \n    print(\"Testing parse_s3_bucket_name():\\n\")\n    for s3_uri, expected in test_cases:\n        result = parse_s3_bucket_name(s3_uri)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} Input: {s3_uri}\")\n        print(f\"  Expected: {expected}, Got: {result}\\n\")\n    \n    # Error cases\n    print(\"\\nTesting error handling:\\n\")\n    error_cases = [\n        ('http://my-bucket/file.txt', \"Invalid S3 URI: must start with 's3://'\"),\n        ('s3://', \"Invalid S3 URI: bucket name is empty\"),\n        (123, \"S3 URI must be a string\"),\n    ]\n    \n    for test_input, expected_error in error_cases:\n        try:\n            parse_s3_bucket_name(test_input)\n            print(f\"\u2717 Expected error for input: {test_input}\")\n        except ValueError as e:\n            print(f\"\u2713 Input: {test_input}\")\n            print(f\"  Caught error: {str(e)}\\n\")\n```\n\n## Output:\n```\nTesting parse_s3_bucket_name():\n\n\u2713 Input: s3://my-bucket/path/to/file.txt\n  Expected: my-bucket, Got: my-bucket\n\n\u2713 Input: s3://another-bucket/\n  Expected: another-bucket, Got: another-bucket\n\n\u2713 Input: s3://simple-bucket\n  Expected: simple-bucket, Got: simple-bucket\n\n\u2713 Input: s3://my-bucket-123/folder/subfolder/file.csv\n  Expected: my-bucket-123, Got: my-bucket-123\n\n\u2713 Input: s3://bucket.with.dots/data.json\n  Expected: bucket.with.dots, Got: bucket.with.dots\n\n\nTesting error handling:\n\n\u2713 Input",
#     "score": 7,
#     "reasoning": "The solution correctly implements the basic requirement and includes good defensive programming with error handling and documentation. However, it lacks validation of bucket naming constraints that AWS enforces, and doesn't account for alternative S3 URI formats that developers might encounter in practice. The manual string parsing approach, while functional, is less maintainable and robust than using urllib.parse. These limitations don't affect the specific task as stated, but would matter in production use."
#   },
#   {
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'company-data'."
#     },
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object representing an IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetBucketLocation\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data\"\n    },\n    {\n      \"Sid\": \"ReadObjectsInBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data/*\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Statement | Purpose |\n|-----------|---------|\n| **ListBucket** | Allows listing bucket contents and retrieving bucket location |\n| **ReadObjectsInBucket** | Allows getting/reading objects from the bucket |\n\n## Key Actions Explained\n\n- `s3:ListBucket` - View the contents of the bucket\n- `s3:GetBucketLocation` - Determine the bucket's AWS region\n- `s3:GetObject` - Read/download objects from the bucket\n- `s3:GetObjectVersion` - Access previous versions of objects (if versioning is enabled)\n\n## Usage\n\nAttach this policy to an IAM user, role, or group to grant read-only S3 access to the 'company-data' bucket.",
#     "score": 8,
#     "reasoning": "The policy correctly addresses the core requirement of read-only S3 access with proper ARN structure and appropriate actions. The documentation is helpful. However, the inclusion of GetObjectVersion without context is a minor concern for strict read-only policies, and the solution could be enhanced with conditional access controls for production use. Overall, this is a solid, working solution suitable for most basic read-only S3 access scenarios."
#   },
#   {
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters, e.g., i-0abcd1234efgh5678)."
#     },
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's a regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Breakdown\n\n| Component | Meaning |\n|-----------|---------|\n| `^` | Start of string |\n| `i-` | Literal \"i-\" prefix |\n| `[0-9a-f]{17}` | Exactly 17 hexadecimal characters (0-9, a-f) |\n| `$` | End of string |\n\n## Examples\n\n### \u2705 Valid Matches\n- `i-0abcd1234efgh5678`\n- `i-1234567890abcdef0`\n- `i-aaaaaaaaaaaaaaaaa`\n- `i-0000000000000000f`\n\n### \u274c Non-Matches\n- `i-0abcd1234efgh567` (only 16 hex chars)\n- `i-0abcd1234efgh56789` (18 hex chars)\n- `i-0abcd1234efghGHIJ` (contains uppercase letters)\n- `i-0abcd1234efgh56g8` (contains 'g', not valid hex)\n- `ec2-0abcd1234efgh5678` (wrong prefix)\n\n## Alternative Variations\n\n**Case-insensitive** (matches uppercase too):\n```regex\n^i-[0-9a-fA-F]{17}$\n```\n\n**Without anchors** (for partial matching):\n```regex\ni-[0-9a-f]{17}\n```",
#     "score": 7,
#     "reasoning": "The core regex pattern is technically correct and will function properly for matching the specified format. However, the solution contains a significant factual error in its examples\u2014the pattern correctly rejects 'g' and 'h' as invalid hex, but the documentation claims 'i-0abcd1234efgh5678' is valid, which is contradictory and misleading. The case-insensitive variant is unnecessary given AWS's actual behavior. Despite these documentation flaws, the primary regex deliverable is accurate and well-explained overall."
#   }
# ]
